# %%
c_unique[cols] = list(data[cols].unique())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\Work_Stuff\churn_minor_project\venv\Lib\site-packages\CleanData.py in <module>
# ----> <a href='file://d:\Work_Stuff\churn_minor_project\venv\Lib\site-packages\CleanData.py?line=11'>12</a> c_unique[cols] = list(data[cols].unique())
#
# NameError: name 'data' is not defined

# %%
import pandas as pd
from Dora import Dora

# %%
data = pd.DataFrame(pd.read_csv('D:\Work_Stuff\churn_minor_project\flaskr\csv\Weather.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Work_Stuff\churn_minor_project\venv\Lib\site-packages\CleanData.py in <module>
# ----> 1 data = pd.DataFrame(pd.read_csv('D:\Work_Stuff\churn_minor_project\flaskr\csv\Weather.csv'))
#
# ...

# %%
data = pd.DataFrame(pd.read_csv('D:\\Work_Stuff\\churn_minor_projec\\flaskr\\csv\\Weather.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Work_Stuff\churn_minor_project\venv\Lib\site-packages\CleanData.py in <module>
# ----> 1 data = pd.DataFrame(pd.read_csv('D:\\Work_Stuff\\churn_minor_projec\\flaskr\\csv\\Weather.csv'))
#
# ...

# %%
data = pd.DataFrame(pd.read_csv('D:/Work_Stuff/churn_minor_project/flaskr/csv/Weather.csv'))

# %%
data
# Out:
#           STA        Date Precip  WindGustSpd    MaxTemp    MinTemp  \
# 0       10001    1942-7-1  1.016          NaN  25.555556  22.222222
# 1       10001    1942-7-2      0          NaN  28.888889  21.666667
# 2       10001    1942-7-3   2.54          NaN  26.111111  22.222222
# 3       10001    1942-7-4   2.54          NaN  26.666667  22.222222
# 4       10001    1942-7-5      0          NaN  26.666667  21.666667
# ...       ...         ...    ...          ...        ...        ...
# 119035  82506  1945-12-27      0          NaN  28.333333  18.333333
# 119036  82506  1945-12-28  9.906          NaN  29.444444  18.333333
# 119037  82506  1945-12-29      0          NaN  28.333333  18.333333
# 119038  82506  1945-12-30      0          NaN  28.333333  18.333333
# 119039  82506  1945-12-31      0          NaN  29.444444  17.222222
#
#          MeanTemp Snowfall PoorWeather  YR  ...  FB  FTI ITH  PGT  TSHDSBRSGF  \
# ...

# %%
dora = dora(output = 0, data = data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-62b206631910> in <module>
# ----> 1 dora = dora(output = 0, data = data)
#
# NameError: name 'dora' is not defined

# %%
from Dora import Dora

# %%
dora = Dora(output=0, data = data)

# %%
dora.data
# Out:
#           STA        Date Precip  WindGustSpd  ...  RHX  RHN  RVG WTE
# 0       10001    1942-7-1  1.016          NaN  ...  NaN  NaN  NaN NaN
# 1       10001    1942-7-2      0          NaN  ...  NaN  NaN  NaN NaN
# 2       10001    1942-7-3   2.54          NaN  ...  NaN  NaN  NaN NaN
# 3       10001    1942-7-4   2.54          NaN  ...  NaN  NaN  NaN NaN
# 4       10001    1942-7-5      0          NaN  ...  NaN  NaN  NaN NaN
# ...       ...         ...    ...          ...  ...  ...  ...  ...  ..
# 119035  82506  1945-12-27      0          NaN  ...  NaN  NaN  NaN NaN
# 119036  82506  1945-12-28  9.906          NaN  ...  NaN  NaN  NaN NaN
# 119037  82506  1945-12-29      0          NaN  ...  NaN  NaN  NaN NaN
# 119038  82506  1945-12-30      0          NaN  ...  NaN  NaN  NaN NaN
# 119039  82506  1945-12-31      0          NaN  ...  NaN  NaN  NaN NaN
#
# [119040 rows x 31 columns]

# %%
dora.data.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# d:\Work_Stuff\churn_minor_project\venv\Lib\site-packages\CleanData.py in <module>
# ----> 1 dora.data.type
#
# d:\Work_Stuff\churn_minor_project\venv\Lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
dora.impute_missing_values()

# %%
dora.data
# Out:
#           STA        Date Precip  WindGustSpd  ...  RHX  RHN  RVG WTE
# 0       10001    1942-7-1  1.016          NaN  ...  NaN  NaN  NaN NaN
# 1       10001    1942-7-2      0          NaN  ...  NaN  NaN  NaN NaN
# 2       10001    1942-7-3   2.54          NaN  ...  NaN  NaN  NaN NaN
# 3       10001    1942-7-4   2.54          NaN  ...  NaN  NaN  NaN NaN
# 4       10001    1942-7-5      0          NaN  ...  NaN  NaN  NaN NaN
# ...       ...         ...    ...          ...  ...  ...  ...  ...  ..
# 119035  82506  1945-12-27      0          NaN  ...  NaN  NaN  NaN NaN
# 119036  82506  1945-12-28  9.906          NaN  ...  NaN  NaN  NaN NaN
# 119037  82506  1945-12-29      0          NaN  ...  NaN  NaN  NaN NaN
# 119038  82506  1945-12-30      0          NaN  ...  NaN  NaN  NaN NaN
# 119039  82506  1945-12-31      0          NaN  ...  NaN  NaN  NaN NaN
#
# [119040 rows x 31 columns]

# %%
data = pd.DataFrame(pd.read_csv('D:/Work_Stuff/churn_minor_project/flaskr/csv/Weather/churn.csv'))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# d:\Work_Stuff\churn_minor_project\venv\Lib\site-packages\CleanData.py in <module>
# ----> 1 data = pd.DataFrame(pd.read_csv('D:/Work_Stuff/churn_minor_project/flaskr/csv/Weather/churn.csv'))
#
# ...

# %%
data = pd.DataFrame(pd.read_csv('D:/Work_Stuff/churn_minor_project/flaskr/csv/churn.csv'))

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
type(data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
data.columns[1]
# Out:
# 'gender'

# %%
data.columns[0]
# Out:
# 'customerID'

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %%
data.dtypes[1]
# Out:
# dtype('O')

# %%
data.dtypes[2]
# Out:
# dtype('int64')

# %%
for dt in data.dtypes:
    print(dt)
# Out:
# object
# object
# int64
# object
# object
# int64
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# float64
# object
# object

# %%
for dt in data.dtypes:
    print(dt, "  ", type(dt))
# Out:
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# float64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>

# %%
for dt in data.dtypes:
    print(dt, "  ", type(dt))
    print(str(dt), "  ", type(dt))
# Out:
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# ...

# %%
for dt in data.dtypes:
    print(str(dt), "  ", type(dt))
# Out:
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# float64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>

# %%
for dt in data.dtypes:
    if dt == 'int64':
        print(dt, "  ", type(dt))
# Out:
# int64    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>

# %%
data
# Out:
#       customerID  gender  SeniorCitizen  ... MonthlyCharges TotalCharges  Churn
# 0     7590-VHVEG  Female              0  ...          29.85        29.85     No
# 1     5575-GNVDE    Male              0  ...          56.95       1889.5     No
# 2     3668-QPYBK    Male              0  ...          53.85       108.15    Yes
# 3     7795-CFOCW    Male              0  ...          42.30      1840.75     No
# 4     9237-HQITU  Female              0  ...          70.70       151.65    Yes
# ...          ...     ...            ...  ...            ...          ...    ...
# 7038  6840-RESVB    Male              0  ...          84.80       1990.5     No
# 7039  2234-XADUH  Female              0  ...         103.20       7362.9     No
# 7040  4801-JZAZL  Female              0  ...          29.60       346.45     No
# 7041  8361-LTMKD    Male              1  ...          74.40        306.6    Yes
# 7042  3186-AJIEK    Male              0  ...         105.65       6844.5     No
#
# ...

# %%
type(data['TotalCharges'])
# Out:
# pandas.core.series.Series

# %%
type(data['Contract'])
# Out:
# pandas.core.series.Series

# %%
type(data.Contract)
# Out:
# pandas.core.series.Series

# %%
data.dtypes[1]
# Out:
# dtype('O')

# %%
data.dtypes[]
# Out:
#   File "<ipython-input-35-fd7658675171>", line 1
#     data.dtypes[]
#                 ^
# SyntaxError: invalid syntax

# %%
data.dtypes[7]
# Out:
# dtype('O')

# %%
data.dtypes[10]
# Out:
# dtype('O')

# %%
data.dtypes[12]
# Out:
# dtype('O')

# %%
data.dtypes[14]
# Out:
# dtype('O')

# %%
data.dtypes[16]
# Out:
# dtype('O')

# %%
data.dtypes[20]
# Out:
# dtype('O')

# %%
data.dtypes[21]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\Work_Stuff\churn_minor_project\venv\Lib\site-packages\pandas\core\indexes\base.py in get_value(self, series, key)
#    4403         try:
# -> 4404             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4405         except KeyError as e1:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 21
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
data.dtypes[19]
# Out:
# dtype('O')

# %%
data.dtypes[18]
# Out:
# dtype('float64')

# %%
c_unique = {}
for cols in data.columns:
    if data.cols == 'o':
        c_unique[cols] = list(data[cols].unique())

# %%
c_unique
# Out:
# {}

# %%
for col in data.columns:
    if data[col].dtypes == 'object':
        print(col)
# Out:
# customerID
# gender
# Partner
# Dependents
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# TotalCharges
# Churn

# %%
c_unique = {}
for cols in data.columns:
    if data[col].dtypes == 'object':
        c_unique[cols] = list(data[cols].unique())

# %%
for key in c_unique:
    print(key, ": ",len(c_unique[key]))
# Out:
# customerID :  7043
# gender :  2
# SeniorCitizen :  2
# Partner :  2
# Dependents :  2
# tenure :  73
# PhoneService :  2
# MultipleLines :  3
# InternetService :  3
# OnlineSecurity :  3
# OnlineBackup :  3
# DeviceProtection :  3
# TechSupport :  3
# StreamingTV :  3
# StreamingMovies :  3
# Contract :  3
# PaperlessBilling :  2
# PaymentMethod :  4
# MonthlyCharges :  1585
# TotalCharges :  6531
# Churn :  2
