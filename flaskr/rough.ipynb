# %%
import pandas as pd
from Dora import Dora

# %%
data = pd.DataFrame(pd.read_csv('D:/Work_Stuff/churn_data_analysis/flaskr/csv/churn.csv'))

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
data.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
type(data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
data.columns[1]
# Out:
# 'gender'

# %%
data.columns[0]
# Out:
# 'customerID'

# %%
data.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
type(data.dtypes)
# Out:
# pandas.core.series.Series

# %%
data.dtypes[1]
# Out:
# dtype('O')

# %%
data.dtypes[2]
# Out:
# dtype('int64')

# %%
for dt in data.dtypes:
    print(dt)
# Out:
# object
# object
# int64
# object
# object
# int64
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# object
# float64
# object
# object

# %%
for dt in data.dtypes:
    print(dt, "  ", type(dt))
# Out:
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# float64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>

# %%
for dt in data.dtypes:
    print(dt, "  ", type(dt))
    print(str(dt), "  ", type(dt))
# Out:
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# ...

# %%
for dt in data.dtypes:
    print(str(dt), "  ", type(dt))
# Out:
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# float64    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>
# object    <class 'numpy.dtype'>

# %%
for dt in data.dtypes:
    if dt == 'int64':
        print(dt, "  ", type(dt))
# Out:
# int64    <class 'numpy.dtype'>
# int64    <class 'numpy.dtype'>

# %%
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
type(data['TotalCharges'])
# Out:
# pandas.core.series.Series

# %%
type(data['Contract'])
# Out:
# pandas.core.series.Series

# %%
type(data.Contract)
# Out:
# pandas.core.series.Series

# %%
data.dtypes[1]
# Out:
# dtype('O')

# %%
data.dtypes[7]
# Out:
# dtype('O')

# %%
data.dtypes[10]
# Out:
# dtype('O')

# %%
data.dtypes[12]
# Out:
# dtype('O')

# %%
data.dtypes[14]
# Out:
# dtype('O')

# %%
data.dtypes[16]
# Out:
# dtype('O')

# %%
data.dtypes[20]
# Out:
# dtype('O')

# %%
data.dtypes[19]
# Out:
# dtype('O')

# %%
data.dtypes[18]
# Out:
# dtype('float64')

# %%
c_unique
# Out:
# {}

# %%
for col in data.columns:
    if data[col].dtypes == 'object':
        print(col)
# Out:
# customerID
# gender
# Partner
# Dependents
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# TotalCharges
# Churn

# %%
c_unique = {}
for cols in data.columns:
    if data[cols].dtypes == 'object':
        print(cols)
        c_unique[cols] = list(data[cols].unique())
# Out:
# customerID
# gender
# Partner
# Dependents
# PhoneService
# MultipleLines
# InternetService
# OnlineSecurity
# OnlineBackup
# DeviceProtection
# TechSupport
# StreamingTV
# StreamingMovies
# Contract
# PaperlessBilling
# PaymentMethod
# TotalCharges
# Churn

# %%
for key in c_unique:
    print(key, ": ",len(c_unique[key]))
# Out:
# customerID :  7043
# gender :  2
# Partner :  2
# Dependents :  2
# PhoneService :  2
# MultipleLines :  3
# InternetService :  3
# OnlineSecurity :  3
# OnlineBackup :  3
# DeviceProtection :  3
# TechSupport :  3
# StreamingTV :  3
# StreamingMovies :  3
# Contract :  3
# PaperlessBilling :  2
# PaymentMethod :  4
# TotalCharges :  6531
# Churn :  2

# %%
faulty_keys = []
for key in c_unique:
    if len(c_unique[key])>50:
        faulty_keys.append(key)
faulty_keys
# Out:
# ['customerID', 'TotalCharges']

# %%
for key in faulty_keys:
    del c_unique[key]
c_unique
# Out:
# {'gender': ['Female', 'Male'],
#  'Partner': ['Yes', 'No'],
#  'Dependents': ['No', 'Yes'],
#  'PhoneService': ['No', 'Yes'],
#  'MultipleLines': ['No phone service', 'No', 'Yes'],
#  'InternetService': ['DSL', 'Fiber optic', 'No'],
#  'OnlineSecurity': ['No', 'Yes', 'No internet service'],
#  'OnlineBackup': ['Yes', 'No', 'No internet service'],
#  'DeviceProtection': ['No', 'Yes', 'No internet service'],
#  'TechSupport': ['No', 'Yes', 'No internet service'],
#  'StreamingTV': ['No', 'Yes', 'No internet service'],
#  'StreamingMovies': ['No', 'Yes', 'No internet service'],
#  'Contract': ['Month-to-month', 'One year', 'Two year'],
#  'PaperlessBilling': ['Yes', 'No'],
#  'PaymentMethod': ['Electronic check',
#   'Mailed check',
#   'Bank transfer (automatic)',
#   'Credit card (automatic)'],
#  'Churn': ['No', 'Yes']}

# %%
r_vals = {}
for key in c_unique:
    distinct = []
    for i in range(0, len(c_unique[key])):
        distinct.append(i)
    r_vals[key] = distinct  

r_vals
# Out:
# {'gender': [0, 1],
#  'Partner': [0, 1],
#  'Dependents': [0, 1],
#  'PhoneService': [0, 1],
#  'MultipleLines': [0, 1, 2],
#  'InternetService': [0, 1, 2],
#  'OnlineSecurity': [0, 1, 2],
#  'OnlineBackup': [0, 1, 2],
#  'DeviceProtection': [0, 1, 2],
#  'TechSupport': [0, 1, 2],
#  'StreamingTV': [0, 1, 2],
#  'StreamingMovies': [0, 1, 2],
#  'Contract': [0, 1, 2],
#  'PaperlessBilling': [0, 1],
#  'PaymentMethod': [0, 1, 2, 3],
#  'Churn': [0, 1]}

# %%
tdata = data

# %%
tdata.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
tdata.drop('customerID', axis=1)
# Out:
#       gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0     Female              0     Yes         No       1           No
# 1       Male              0      No         No      34          Yes
# 2       Male              0      No         No       2          Yes
# 3       Male              0      No         No      45           No
# 4     Female              0      No         No       2          Yes
# ...      ...            ...     ...        ...     ...          ...
# 7038    Male              0     Yes        Yes      24          Yes
# 7039  Female              0     Yes        Yes      72          Yes
# 7040  Female              0     Yes        Yes      11           No
# 7041    Male              1     Yes         No       4          Yes
# 7042    Male              0      No         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
tdata.drop(['gender', 'Partner'], axis=1)
# Out:
#       customerID  SeniorCitizen Dependents  tenure PhoneService  \
# 0     7590-VHVEG              0         No       1           No
# 1     5575-GNVDE              0         No      34          Yes
# 2     3668-QPYBK              0         No       2          Yes
# 3     7795-CFOCW              0         No      45           No
# 4     9237-HQITU              0         No       2          Yes
# ...          ...            ...        ...     ...          ...
# 7038  6840-RESVB              0        Yes      24          Yes
# 7039  2234-XADUH              0        Yes      72          Yes
# 7040  4801-JZAZL              0        Yes      11           No
# 7041  8361-LTMKD              1         No       4          Yes
# 7042  3186-AJIEK              0         No      66          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 0     No phone service             DSL             No          Yes
# ...

# %%
tdata.to_json(orient='records')
# Out:
# ies":"No internet service","Contract":"One year","PaperlessBilling":"No","PaymentMethod":"Electronic check","MonthlyCharges":20.55,"TotalCharges":"1343.4","Churn":"No"},{"customerID":"6304-IJFSQ","gender":"Male","SeniorCitizen":0,"Partner":"No","Dependents":"No","tenure":3,"PhoneService":"Yes","MultipleLines":"No","InternetService":"DSL","OnlineSecurity":"No","OnlineBackup":"Yes","DeviceProtection":"No","TechSupport":"No","StreamingTV":"No","StreamingMovies":"No","Contract":"Month-to-month","PaperlessBilling":"Yes","PaymentMethod":"Mailed check","MonthlyCharges":49.9,"TotalCharges":"130.1","Churn":"Yes"},{"customerID":"9586-JGQKH","gender":"Female","SeniorCitizen":0,"Partner":"Yes","Dependents":"No","tenure":64,"PhoneService":"Yes","MultipleLines":"Yes","InternetService":"Fiber optic","OnlineSecurity":"No","OnlineBackup":"Yes","DeviceProtection":"No","TechSupport":"Yes","StreamingTV":"Yes","StreamingMovies":"Yes","Contract":"Two year","PaperlessBilling":"Yes","PaymentMethod":"Bank tr
# ...
